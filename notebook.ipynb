# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv("data/train.csv")
df_cv = pd.read_csv("data/val.csv")
df_train.head()
print(f"columns = {df_train.columns}")
print("\n")
print(f"Train set size = {df_train.shape[0]}")
print(f"CV set size = {df_cv.shape[0]}")
# Out:
# columns = Index(['rowid', 'kepid', 'kepoi_name', 'kepler_name', 'koi_disposition',
#        'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
#        'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1',
#        'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
#        'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
#        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
#        'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
#        'koi_prad_err2', 'koi_teq', 'koi_insol', 'koi_insol_err1',
#        'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff',
#        'koi_steff_err1', 'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1',
#        'koi_slogg_err2', 'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra',
#        'dec', 'koi_kepmag'],
#       dtype='object')
#
#
# Train set size = 6695
# CV set size = 956

# %%
def create_sns_countPlot(X, title):
    sns.countplot(data = X, x = "koi_pdisposition", hue = "koi_pdisposition", palette = "magma")
    plt.legend(labels = ["Candidate", "False Positive"])
    plt.title(title)
    plt.tight_layout()
    plt.show()

# %%
create_sns_countPlot(df_train, "Bias in Train set")

# %%
create_sns_countPlot(df_cv, "Bias in CV set")
